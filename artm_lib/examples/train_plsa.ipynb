# %%
# artm_lib/examples/train_plsa.py

import numpy as np
import jax.numpy as jnp

from sklearn.datasets import fetch_20newsgroups
from cartm.preprocessing import DatasetPreprocessor

from artm_lib.plsa.model import PLSA
from scipy.sparse import csr_matrix

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data = fetch_20newsgroups(data_home='../data/', subset='all').data
print(f'Total number of documents in corpus: {len(data)}')
print(f'Total number of words in corpus: {sum([len(doc.split(" ")) for doc in data])}')
# Out:
# Total number of documents in corpus: 18846
# Total number of words in corpus: 5937230

# %%
with open('../../data/test_data.txt') as f:
    data = f.readlines()
print(f'Total number of documents in corpus: {len(data)}')
print(f'Total number of words in corpus: {sum([len(doc.split(" ")) for doc in data])}')
# Out:
# Total number of documents in corpus: 4
# Total number of words in corpus: 34

# %%
preprocessor = DatasetPreprocessor(stopwords=[], min_word_len=0)
tokenized_docs = preprocessor.fit_transform_plsa(data)
print(f'Total number of documents in preprocessed corpus: {len(tokenized_docs)}')
tokenized_docs.shape
# Out:
# vocab_size=90905
# W0405 20:43:29.844225  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:43:29.849067  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:43:39.858782  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:43:39.862691  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:43:49.867857  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:43:49.872004  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:43:59.877182  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:43:59.881576  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:09.885960  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:09.890123  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:19.897172  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:19.901480  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:29.907404  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:29.911605  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:39.917581  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:39.921803  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:49.928016  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:49.933464  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:44:59.938529  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:44:59.942828  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:45:09.948516  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:45:09.952211  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:45:19.958528  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:45:19.962949  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:45:29.968854  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:45:29.973084  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:45:39.978221  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:45:39.982418  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:45:50.436451  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:45:50.440482  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:46:00.446546  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:46:00.450915  591977 bfc_allocator.cc:513] ****************************************************************************************************
# W0405 20:46:10.460230  591977 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 355.1KiB (rounded to 363776)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# W0405 20:46:10.464587  591977 bfc_allocator.cc:513] ****************************************************************************************************

# %%
vocabulary = preprocessor.vocabulary

for i, (word, token) in enumerate(vocabulary.items()):
    print(f'{word}: {token}')
    #if i == 10:
    #    break

reverse_vocab = {value: key for key, value in vocabulary.items()}
#[reverse_vocab[t] for t in tokenized_data.tolist()]
# Out:
# today: 0
# small: 1
# lead: 2
# time: 3
# if: 4
# tri: 5
# disconnect: 6
# would: 7
# you: 8
# everi: 9
# now: 10
# sometim: 11
# best: 12
# were: 13
# is: 14
# new: 15
# big: 16
# begin: 17
# day: 18
# i: 19
# need: 20
# to: 21
# reconnect: 22
# the: 23
# a: 24
# step: 25
# someth: 26
# for: 27
# result: 28

# %%
tokenized_docs.shape
#reverse_vocab[20]
#len(vocabulary)
# Out:
# (4, 29)

# %%
V = len(vocabulary)
model = PLSA(
    n_topics=10, 
    vocab_size=V, 
    random_state=42
)

history = model.data_fit_full(
    data=csr_matrix(tokenized_docs),
    n_epochs=100,
    tol=1e-4,
    verbose=True,
)
# Out:
# Iter 0: train_perp=24.78, diff=0.340696
# Iter 10: train_perp=8.18, diff=0.033667
# Iter 20: train_perp=8.18, diff=0.014093
# Iter 30: train_perp=8.19, diff=0.007148
# Iter 40: train_perp=8.19, diff=0.003739
# Iter 50: train_perp=8.20, diff=0.002954
# Iter 60: train_perp=8.20, diff=0.002945
# Iter 70: train_perp=8.21, diff=0.003063
# Iter 80: train_perp=8.21, diff=0.003224
# Iter 90: train_perp=8.22, diff=0.003427
# Iter 99: train_perp=8.22, diff=0.003641
